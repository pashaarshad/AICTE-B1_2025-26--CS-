# %%
print("HI")
# Out:
# HI

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.58.4-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (106 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# ...
# Using cached matplotlib-3.10.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Using cached contourpy-1.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.58.4-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
# ...

# %%
#import libarary
import cv2 
import numpy as np
import string
import os
import matplotlib.pyplot as plt

# %%
# !pip install opencv-python

# %%
#ASCII Conversion
d={chr(i):i for i in range(255)} # char to ascii
c={i:chr(i) for i in range(255)}  # reciver-end  ascii to caharacter

# %%
#Loaning the img
image_path = r"/home/arshad/Desktop/Internships --All Code and Projects/AICTE B1_2025-26 (CS)/img2.jpeg"
x=cv2.imread(image_path)
x # as print ... ok arshad

xrgb = cv2.cvtColor(x, cv2.COLOR_BGR2RGB)
plt.imshow(xrgb)
plt.axis('off')
plt.show()

# %%
x.shape
# Out:
# (164, 308, 3)

# %%
key="123"
text="secret"

# %%
key
# Out:
# '123'

# %%
# ASCII values 
text_ascii=[d[ch] for ch in text]
key_ascii=[d[ch] for ch in key]

print(text_ascii)
key_ascii
# Out:
# [115, 101, 99, 114, 101, 116]
# [49, 50, 51]

# %%
#Encrypt using pixel modelfication 
x_enc=x.copy()
# print if you needed  x_enc
#c,r,colorpanle
n=0  #num of rows
m=0 # num of clooums
z=0 #colour panel
l=len(text)
kl=0
for i in range(l):
    orig_val=x_enc(n,m,z)
    new_val=d[text[i]] ^ d[key[i]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 11
#       9 kl=0
#      10 for i in range(l):
# ---> 11     orig_val=x_enc(n,m,z)
#      12     new_val=d[text[i]] ^ d[key[i]]
#
# TypeError: 'numpy.ndarray' object is not callable
